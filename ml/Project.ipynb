# %% [markdown]
# # Data Analysis Project - Protein Features
#
# This notebook performs:
# 1. Data Loading and Preprocessing
# 2. Exploratory Data Analysis (EDA)
# 3. Data Imbalance Handling

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Set visualization style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## 2. Load Data and Initial Exploration

# %%
# Load the CSV file
df = pd.read_csv('protein_features.csv')

print(f"Dataset shape: {df.shape}")
print(f"\nFirst few rows:")
df.head()
# Out:
# Dataset shape: (140271, 46)
#
# First few rows:
#                  ID                                   Recommended Name  \
# 0  A0A6G0UGL8_9BILA                   receptor protein-tyrosine kinase
# 1  A0A2K6SKD5_SAIBB                   Tyrosine-protein kinase receptor
# 2  A0A836ABD7_SHEEP  Solute carrier family 2, facilitated glucose t...
# 3  A0A6P3RGQ7_PTEVA  Phosphatidylinositol 5-phosphate 4-kinase type...
# 4  A0A3B3DRK3_ORYME                   Tyrosine-protein kinase receptor
#
#   Submitted Names Gene name  \
# 0             NaN       NaN
# 1             NaN       LTK
# 2             NaN       NaN
# 3             NaN     KIF5A
# 4             NaN       NaN
#
#                                    Taxonomic lineage  \
# 0  Eukaryota | Metazoa | Ecdysozoa | Nematoda | C...
# 1  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 2  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 3  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 4  Eukaryota | Metazoa | Chordata | Craniata | Ve...
#
#                 Cellular components:  \
# 0           Cell membrane | Membrane
# 1           Cell membrane | Membrane
# 2           Cell membrane | Membrane
# 3  Cytoplasm | Endoplasmic reticulum
# 4           Cell membrane | Membrane
#
#                                              Domain:  \
# 0       Signal | Transmembrane | Transmembrane helix
# 1       Signal | Transmembrane | Transmembrane helix
# 2                Transmembrane | Transmembrane helix
# 3                                                NaN
# 4  Immunoglobulin domain | Leucine-rich repeat | ...
#
#                                              Family:  \
# 0  Belongs to the protein kinase superfamily. Tyr...
# 1  Belongs to the protein kinase superfamily. Tyr...
# 2  Belongs to the major facilitator superfamily. ...
# 3                                                NaN
# 4  Belongs to the protein kinase superfamily. Tyr...
#
#               Biological process:  \
# 0                   Cell adhesion
# 1                             NaN
# 2                             NaN
# 3                Lipid metabolism
# 4  Differentiation | Neurogenesis
#
#                                            Function:  ...  \
# 0  Kinase | Receptor | Transferase | Tyrosine-pro...  ...
# 1  Kinase | Receptor | Transferase | Tyrosine-pro...  ...
# 2                                  GTPase activation  ...
# 3                               Kinase | Transferase  ...
# 4  Developmental protein | Kinase | Receptor | Tr...  ...
#
#   Group_Negative_Hydrophobic  Group_Negative_Polar  Group_Negative_Positive  \
# 0                   0.048984              0.045400                 0.010753
# 1                   0.047919              0.018916                 0.006305
# 2                   0.042553              0.022744                 0.007337
# 3                   0.052257              0.028504                 0.014252
# 4                   0.056860              0.028430                 0.004944
#
#    Group_Negative_Negative  Group_Negative_Special  Group_Special_Hydrophobic  \
# 0                 0.021505                0.013142                   0.023895
# 1                 0.008827                0.012610                   0.050441
# 2                 0.012472                0.008070                   0.036684
# 3                 0.023753                0.016627                   0.040380
# 4                 0.009889                0.008653                   0.027194
#
#    Group_Special_Polar  Group_Special_Positive Group_Special_Negative  \
# 0             0.017921                0.013142               0.005974
# 1             0.018916                0.011349               0.013871
# 2             0.017608                0.010271               0.005869
# 3             0.016627                0.002375               0.009501
# 4             0.017305                0.012361               0.009889
#
#   Group_Special_Special
# 0              0.000000
# 1              0.022699
# 2              0.006603
# 3              0.002375
# 4              0.001236
#
# [5 rows x 46 columns]

# %%
# Check data info
print("Dataset Information:")
print(f"Shape: {df.shape}")
print(f"\nColumn names:")
print(df.columns.tolist())
print(f"\nData types:")
df.dtypes
# Out:
# Dataset Information:
# Shape: (140271, 46)
#
# Column names:
# ['ID', 'Recommended Name', 'Submitted Names', 'Gene name', 'Taxonomic lineage', 'Cellular components:', 'Domain:', 'Family:', 'Biological process:', 'Function:', 'Sequence:', 'Length:', 'Molecular weight:', 'Number of interactors:', 'pI', 'Net_Charge_7_4', 'Hydrophobicity_GRAVY', 'Depth_Rank', 'Last_Rank', 'First_Rank', 'Sequence_Chunks', 'Group_Hydrophobic_Hydrophobic', 'Group_Hydrophobic_Polar', 'Group_Hydrophobic_Positive', 'Group_Hydrophobic_Negative', 'Group_Hydrophobic_Special', 'Group_Polar_Hydrophobic', 'Group_Polar_Polar', 'Group_Polar_Positive', 'Group_Polar_Negative', 'Group_Polar_Special', 'Group_Positive_Hydrophobic', 'Group_Positive_Polar', 'Group_Positive_Positive', 'Group_Positive_Negative', 'Group_Positive_Special', 'Group_Negative_Hydrophobic', 'Group_Negative_Polar', 'Group_Negative_Positive', 'Group_Negative_Negative', 'Group_Negative_Special', 'Group_Special_Hydrophobic', 'Group_Special_Polar', 'Group_Special_Positive', 'Group_Special_Negative', 'Group_Special_Special']
#
# Data types:
# ID                                object
# Recommended Name                  object
# Submitted Names                   object
# Gene name                         object
# Taxonomic lineage                 object
# Cellular components:              object
# Domain:                           object
# Family:                           object
# Biological process:               object
# Function:                         object
# Sequence:                         object
# Length:                            int64
# Molecular weight:                  int64
# Number of interactors:             int64
# pI                               float64
# Net_Charge_7_4                   float64
# Hydrophobicity_GRAVY             float64
# Depth_Rank                         int64
# Last_Rank                         object
# First_Rank                        object
# Sequence_Chunks                   object
# Group_Hydrophobic_Hydrophobic    float64
# Group_Hydrophobic_Polar          float64
# Group_Hydrophobic_Positive       float64
# Group_Hydrophobic_Negative       float64
# Group_Hydrophobic_Special        float64
# Group_Polar_Hydrophobic          float64
# Group_Polar_Polar                float64
# Group_Polar_Positive             float64
# Group_Polar_Negative             float64
# Group_Polar_Special              float64
# Group_Positive_Hydrophobic       float64
# Group_Positive_Polar             float64
# Group_Positive_Positive          float64
# Group_Positive_Negative          float64
# Group_Positive_Special           float64
# Group_Negative_Hydrophobic       float64
# Group_Negative_Polar             float64
# Group_Negative_Positive          float64
# Group_Negative_Negative          float64
# Group_Negative_Special           float64
# Group_Special_Hydrophobic        float64
# Group_Special_Polar              float64
# Group_Special_Positive           float64
# Group_Special_Negative           float64
# Group_Special_Special            float64
# dtype: object

# %%
df = df[["ID","Recommended Name","Submitted Names", "Gene name", "Taxonomic lineage", "Cellular components:", "Domain:", "Family:", "Biological process:", "Function:", "Sequence:", "Length:", "Molecular weight:", "Number of interactors:", "pI", "Net_Charge_7_4", "Hydrophobicity_GRAVY", "Depth_Rank", "Last_Rank", "First_Rank", "Sequence_Chunks"]]

# %%
data = df["Recommended Name"].fillna(df["Submitted Names"])
df.insert(1, "Name", data)

# %%
df
# Out:
#                       ID                                               Name  \
# 0       A0A6G0UGL8_9BILA                   receptor protein-tyrosine kinase
# 1       A0A2K6SKD5_SAIBB                   Tyrosine-protein kinase receptor
# 2       A0A836ABD7_SHEEP  Solute carrier family 2, facilitated glucose t...
# 3       A0A6P3RGQ7_PTEVA  Phosphatidylinositol 5-phosphate 4-kinase type...
# 4       A0A3B3DRK3_ORYME                   Tyrosine-protein kinase receptor
# ...                  ...                                                ...
# 140266      H3D1B6_TETNG                                ISL LIM homeobox 2b
# 140267  A0A7L0QEG3_SETKR                                        R-spondin-3
# 140268  A0A850V5Z5_9CORV                                            Insulin
# 140269  A0A8C2VZR5_CHILA               Cartilage intermediate layer protein
# 140270  A0A8D0L905_SPHPU                                            Tuberin
#
#                                          Recommended Name  \
# 0                        receptor protein-tyrosine kinase
# 1                        Tyrosine-protein kinase receptor
# 2       Solute carrier family 2, facilitated glucose t...
# 3       Phosphatidylinositol 5-phosphate 4-kinase type...
# 4                        Tyrosine-protein kinase receptor
# ...                                                   ...
# 140266                                                NaN
# 140267                                        R-spondin-3
# 140268                                            Insulin
# 140269                                                NaN
# 140270                                            Tuberin
#
#                              Submitted Names Gene name  \
# 0                                        NaN       NaN
# 1                                        NaN       LTK
# 2                                        NaN       NaN
# 3                                        NaN     KIF5A
# 4                                        NaN       NaN
# ...                                      ...       ...
# 140266                   ISL LIM homeobox 2b       NaN
# 140267                                   NaN     Rspo3
# 140268                                   NaN       Ins
# 140269  Cartilage intermediate layer protein      CILP
# 140270                                   NaN      TSC2
#
#                                         Taxonomic lineage  \
# 0       Eukaryota | Metazoa | Ecdysozoa | Nematoda | C...
# 1       Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 2       Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 3       Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 4       Eukaryota | Metazoa | Chordata | Craniata | Ve...
# ...                                                   ...
# 140266  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 140267  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 140268  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 140269  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 140270  Eukaryota | Metazoa | Chordata | Craniata | Ve...
#
#                      Cellular components:  \
# 0                Cell membrane | Membrane
# 1                Cell membrane | Membrane
# 2                Cell membrane | Membrane
# 3       Cytoplasm | Endoplasmic reticulum
# 4                Cell membrane | Membrane
# ...                                   ...
# 140266                            Nucleus
# 140267                           Secreted
# 140268                           Secreted
# 140269    Extracellular matrix | Secreted
# 140270    Cytoplasm | Lysosome | Membrane
#
#                                                   Domain:  \
# 0            Signal | Transmembrane | Transmembrane helix
# 1            Signal | Transmembrane | Transmembrane helix
# 2                     Transmembrane | Transmembrane helix
# 3                                                     NaN
# 4       Immunoglobulin domain | Leucine-rich repeat | ...
# ...                                                   ...
# 140266                     Homeobox | LIM domain | Repeat
# 140267                                    Repeat | Signal
# 140268                                             Signal
# 140269                     Immunoglobulin domain | Signal
# 140270                                                NaN
#
#                                                   Family:  \
# 0       Belongs to the protein kinase superfamily. Tyr...
# 1       Belongs to the protein kinase superfamily. Tyr...
# 2       Belongs to the major facilitator superfamily. ...
# 3                                                     NaN
# 4       Belongs to the protein kinase superfamily. Tyr...
# ...                                                   ...
# 140266                                                NaN
# 140267                    Belongs to the R-spondin family
# 140268                      Belongs to the insulin family
# 140269                                                NaN
# 140270                                                NaN
#
#                                  Biological process:  ... Length:  \
# 0                                      Cell adhesion  ...     838
# 1                                                NaN  ...     794
# 2                                                NaN  ...    1364
# 3                                   Lipid metabolism  ...     422
# 4                     Differentiation | Neurogenesis  ...     810
# ...                                              ...  ...     ...
# 140266                                 Transcription  ...     362
# 140267  Sensory transduction | Wnt signaling pathway  ...     243
# 140268  Carbohydrate metabolism | Glucose metabolism  ...     105
# 140269                                           NaN  ...    1190
# 140270                                           NaN  ...    1737
#
#        Molecular weight:  Number of interactors:        pI  Net_Charge_7_4  \
# 0                  95462                       0  5.518918      -17.586081
# 1                  84804                       0  5.804307      -12.713834
# 2                 149825                       0  8.640005       11.644155
# 3                  47259                       0  6.360874       -5.279498
# 4                  92125                       0  6.064459      -13.407168
# ...                  ...                     ...       ...             ...
# 140266             40457                     201  8.289168        3.402710
# 140267             27409                       0  9.391770       23.097770
# 140268             11794                       0  5.526705       -3.758263
# 140269            132470                       0  8.589719       14.987649
# 140270            194440                       0  6.408051      -13.796634
#
#         Hydrophobicity_GRAVY  Depth_Rank        Last_Rank  First_Rank  \
# 0                  -0.435322          11   Halicephalobus  Eukaryota
# 1                  -0.113350          15          Saimiri  Eukaryota
# 2                  -0.051760          15             Ovis  Eukaryota
# 3                  -0.388389          15         Pteropus  Eukaryota
# 4                  -0.165185          17          Oryzias  Eukaryota
# ...                      ...         ...              ...         ...
# 140266             -0.450829          16        Tetraodon  Eukaryota
# 140267             -1.103292          21        Setophaga  Eukaryota
# 140268             -0.029524          21       Chloropsis  Eukaryota
# 140269             -0.485042          14       Chinchilla  Eukaryota
# 140270             -0.230455          10        Sphenodon  Eukaryota
#
#                                           Sequence_Chunks
# 0       ['MTDRVLDRQC', 'NKALGMESGR', 'IKDSQISASS', 'SF...
# 1       ['MGRWGLLLGW', 'FGAAGAILCS', 'CSQEPFLQSS', 'PR...
# 2       ['MELEPGGAAA', 'ALLRQKRAAL', 'RRRGCSFESP', 'ST...
# 3       ['MASSSAPPAT', 'VPATTAAPGP', 'GFGFASKTKK', 'KH...
# 4       ['MDLWFHSIRI', 'CWWRVLFLMS', 'IFQDYLSSML', 'DC...
# ...                                                   ...
# 140266  ['MVDIIFSSSF', 'LGDMGDHSKK', 'KQGFAMCVGC', 'GS...
# 140267  ['VHPNVSQGCQ', 'GGCATCSDYN', 'GCLSCKPRLF', 'FV...
# 140268  ['MALWIRSLPL', 'LALLALSSPG', 'SIQGAVNQHL', 'CG...
# 140269  ['MEGAEAWLFS', 'FLVLQVASVL', 'PGPSRRENRA', 'HP...
# 140270  ['LEGRCAGQVS', 'MAKPQSKDPG', 'LREKFKNLLG', 'LG...
#
# [140271 rows x 22 columns]

# %%
df.drop(columns=["Recommended Name", "Submitted Names", "Sequence:"], inplace=True)
df
# Out:
#                       ID                                               Name  \
# 0       A0A6G0UGL8_9BILA                   receptor protein-tyrosine kinase
# 1       A0A2K6SKD5_SAIBB                   Tyrosine-protein kinase receptor
# 2       A0A836ABD7_SHEEP  Solute carrier family 2, facilitated glucose t...
# 3       A0A6P3RGQ7_PTEVA  Phosphatidylinositol 5-phosphate 4-kinase type...
# 4       A0A3B3DRK3_ORYME                   Tyrosine-protein kinase receptor
# ...                  ...                                                ...
# 140266      H3D1B6_TETNG                                ISL LIM homeobox 2b
# 140267  A0A7L0QEG3_SETKR                                        R-spondin-3
# 140268  A0A850V5Z5_9CORV                                            Insulin
# 140269  A0A8C2VZR5_CHILA               Cartilage intermediate layer protein
# 140270  A0A8D0L905_SPHPU                                            Tuberin
#
#        Gene name                                  Taxonomic lineage  \
# 0            NaN  Eukaryota | Metazoa | Ecdysozoa | Nematoda | C...
# 1            LTK  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 2            NaN  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 3          KIF5A  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 4            NaN  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# ...          ...                                                ...
# 140266       NaN  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 140267     Rspo3  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 140268       Ins  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 140269      CILP  Eukaryota | Metazoa | Chordata | Craniata | Ve...
# 140270      TSC2  Eukaryota | Metazoa | Chordata | Craniata | Ve...
#
#                      Cellular components:  \
# 0                Cell membrane | Membrane
# 1                Cell membrane | Membrane
# 2                Cell membrane | Membrane
# 3       Cytoplasm | Endoplasmic reticulum
# 4                Cell membrane | Membrane
# ...                                   ...
# 140266                            Nucleus
# 140267                           Secreted
# 140268                           Secreted
# 140269    Extracellular matrix | Secreted
# 140270    Cytoplasm | Lysosome | Membrane
#
#                                                   Domain:  \
# 0            Signal | Transmembrane | Transmembrane helix
# 1            Signal | Transmembrane | Transmembrane helix
# 2                     Transmembrane | Transmembrane helix
# 3                                                     NaN
# 4       Immunoglobulin domain | Leucine-rich repeat | ...
# ...                                                   ...
# 140266                     Homeobox | LIM domain | Repeat
# 140267                                    Repeat | Signal
# 140268                                             Signal
# 140269                     Immunoglobulin domain | Signal
# 140270                                                NaN
#
#                                                   Family:  \
# 0       Belongs to the protein kinase superfamily. Tyr...
# 1       Belongs to the protein kinase superfamily. Tyr...
# 2       Belongs to the major facilitator superfamily. ...
# 3                                                     NaN
# 4       Belongs to the protein kinase superfamily. Tyr...
# ...                                                   ...
# 140266                                                NaN
# 140267                    Belongs to the R-spondin family
# 140268                      Belongs to the insulin family
# 140269                                                NaN
# 140270                                                NaN
#
#                                  Biological process:  \
# 0                                      Cell adhesion
# 1                                                NaN
# 2                                                NaN
# 3                                   Lipid metabolism
# 4                     Differentiation | Neurogenesis
# ...                                              ...
# 140266                                 Transcription
# 140267  Sensory transduction | Wnt signaling pathway
# 140268  Carbohydrate metabolism | Glucose metabolism
# 140269                                           NaN
# 140270                                           NaN
#
#                                                 Function:  Length:  \
# 0       Kinase | Receptor | Transferase | Tyrosine-pro...      838
# 1       Kinase | Receptor | Transferase | Tyrosine-pro...      794
# 2                                       GTPase activation     1364
# 3                                    Kinase | Transferase      422
# 4       Developmental protein | Kinase | Receptor | Tr...      810
# ...                                                   ...      ...
# 140266                Developmental protein | DNA-binding      362
# 140267                                    Heparin-binding      243
# 140268                                            Hormone      105
# 140269                                                NaN     1190
# 140270                                  GTPase activation     1737
#
#         Molecular weight:  Number of interactors:        pI  Net_Charge_7_4  \
# 0                   95462                       0  5.518918      -17.586081
# 1                   84804                       0  5.804307      -12.713834
# 2                  149825                       0  8.640005       11.644155
# 3                   47259                       0  6.360874       -5.279498
# 4                   92125                       0  6.064459      -13.407168
# ...                   ...                     ...       ...             ...
# 140266              40457                     201  8.289168        3.402710
# 140267              27409                       0  9.391770       23.097770
# 140268              11794                       0  5.526705       -3.758263
# 140269             132470                       0  8.589719       14.987649
# 140270             194440                       0  6.408051      -13.796634
#
#         Hydrophobicity_GRAVY  Depth_Rank        Last_Rank  First_Rank  \
# 0                  -0.435322          11   Halicephalobus  Eukaryota
# 1                  -0.113350          15          Saimiri  Eukaryota
# 2                  -0.051760          15             Ovis  Eukaryota
# 3                  -0.388389          15         Pteropus  Eukaryota
# 4                  -0.165185          17          Oryzias  Eukaryota
# ...                      ...         ...              ...         ...
# 140266             -0.450829          16        Tetraodon  Eukaryota
# 140267             -1.103292          21        Setophaga  Eukaryota
# 140268             -0.029524          21       Chloropsis  Eukaryota
# 140269             -0.485042          14       Chinchilla  Eukaryota
# 140270             -0.230455          10        Sphenodon  Eukaryota
#
#                                           Sequence_Chunks
# 0       ['MTDRVLDRQC', 'NKALGMESGR', 'IKDSQISASS', 'SF...
# 1       ['MGRWGLLLGW', 'FGAAGAILCS', 'CSQEPFLQSS', 'PR...
# 2       ['MELEPGGAAA', 'ALLRQKRAAL', 'RRRGCSFESP', 'ST...
# 3       ['MASSSAPPAT', 'VPATTAAPGP', 'GFGFASKTKK', 'KH...
# 4       ['MDLWFHSIRI', 'CWWRVLFLMS', 'IFQDYLSSML', 'DC...
# ...                                                   ...
# 140266  ['MVDIIFSSSF', 'LGDMGDHSKK', 'KQGFAMCVGC', 'GS...
# 140267  ['VHPNVSQGCQ', 'GGCATCSDYN', 'GCLSCKPRLF', 'FV...
# 140268  ['MALWIRSLPL', 'LALLALSSPG', 'SIQGAVNQHL', 'CG...
# 140269  ['MEGAEAWLFS', 'FLVLQVASVL', 'PGPSRRENRA', 'HP...
# 140270  ['LEGRCAGQVS', 'MAKPQSKDPG', 'LREKFKNLLG', 'LG...
#
# [140271 rows x 19 columns]

# %%
with open('protein_features_cleaned_combine.csv', 'w') as f:
    df.to_csv(f, index=False)
